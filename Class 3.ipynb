# %%
# python list

mylist = [1, 2, 3, 4]

# help(mylist)

print(mylist)
# Out:
# [1, 2, 3, 4]

# %%
class SinglyLinkedList:
    class __Node:
        def __init__(self, data):
            self.data = data
            self.next = None
    
    def __init__(self):
            self.head = None
            
    def append(self, value):
        new_node = self.__Node(value)
        if not self.head:           # state 1: when the list is empty
            self.head = new_node
        else:
            current = self.head     # state 2: when there is only one node and...
            while current.next:     # state 3: when there is more than one node in our list.
                current = current.next
            current.next = new_node
                
    def __str__(self):
        # if self.head = None, return list in a string format "[]"
        # create a "output" var with open bracket
        # if self.head, unite with output var
        # on self.next, add "," string values per value 
        out = "["
        current = self.head
        if current:
            out += "%s" % current.data
            current = current.next
            while current:
                out += ", %s" % current.data
                current = current.next
        out += "]"
        return out
            
    def insert(self, index, value):
        if index < 0:
            raise ValueError("Invalid index")
            
        new_node = self.__Node(element)
        
        if index == 0:
            new_node.next = self.head
            self.head = new_node
        else:
            current = self.head
            counter = 0
            while current and index != counter:
                self.prev = current
                current = current.next
                counter += 1
                
        new_node.next = current
        self.prev = new_node
        
    def remove(self,  value):
        # conditional statement verify if list is empty before searching for value by applying if statements
        # search for value entered by comparing with self.head.data, then return
        # use while loop, to iterate each element until identical value is found, raise ValueError if not found
        if not self.head:
            raise ValueError("List is empty")
        if self.head.data == value:
            self.head = self.head.next
        else:
            current = self.head
            previous = None
            while current:
                if current.data == value:
                    previous.next = current.next
                else:
                    previous = current
                    current = current.next
        raise ValueError("Value not found in current list")
        
        
    def index(self, value):
        # return first index of value or ValueError if not present
        current = self.head
        counter = 0
        found = False
        if current:                            #shorthand for if current != None
            while current.next and not found:
                if current.data == value:
                    found = True
                    break
                counter += 1
                current = current.next
        if found:
            return counter
        raise ValueError("Value not found")

# %%
sll = SinglyLinkedList()
python_list = []
    
print("Empty lists:")
print(sll)
print(python_list)
    
print("Lists with one element:")
sll.append(1)
print(sll)
python_list.append(1)
python_list.append(5)
print(python_list)
    
print("List with more one than one element:")
for number in range(2, 5):
    python_list.append(number)
    sll.append(number)
    
print(sll)
print(python_list)

print("Remove an element:")

python_list.remove(3)
print(python_list)

sll.remove(3)
print(sll)
# Out:
# Empty lists:
# []
# []
# Lists with one element:
# [1]
# [1, 5]
# List with more one than one element:
# [1, 2, 3, 4]
# [1, 5, 2, 3, 4]
# Remove an element:
# [1, 5, 2, 4]
